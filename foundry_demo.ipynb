# %% [markdown]
# # ASPECTOR Foundry Demo
#
# This notebook demonstrates the use of the ASPECTOR Foundry to output single-ended and differential op-amp designs in `.scs` Spectre netlist format.
#
# ## Imports
#
# Import necessary modules from `components.py`, `templates.py`, and `generator.py`.

# %%
import components
import templates
from generator import NetlistGenerator

# %% [markdown]
# ## Generate Single Ended Op-Amp Designs
#
# Create 5 randomly synthesized single ended op-amp designs with 7 nfets, 7pfets, 2 resistors, and 2 capactitors each.

# %%
# define number of circuit components
n_nfet_se = 7
n_pfet_se = 7
n_res_se = 2
n_cap_se = 1
mode_se = "single_ended"
max_netlists_se = 5

# define generator object
gen_se = NetlistGenerator(n_nfet_se, n_pfet_se, n_res_se, n_cap_se, mode_se)

# generate netlists
gen_se.generate_random(max_netlists_se)
# Out:
# Written results/single_ended1.scs
# Written results/single_ended2.scs
# Written results/single_ended3.scs
# Written results/single_ended4.scs
# Written results/single_ended5.scs

# %% [markdown]
# ## Generate Single Ended Op-Amp Designs
#
# Create 5 randomly synthesized fully differential op-amp designs with 4 nfets, 8 pfets, 1 resistor, and 1 capactitor each.

# %%
# define number of circuit components
n_nfet_diff = 4
n_pfet_diff = 8
n_res_diff = 1
n_cap_diff = 1
mode_diff = "differential"
max_netlists_diff = 5

# define generator object
gen_diff = NetlistGenerator(n_nfet_diff, n_pfet_diff, n_res_diff, n_cap_diff, mode_diff)

# generate netlists
gen_diff.generate_random(max_netlists_diff)
# Out:
# Written results/differential1.scs
# Written results/differential2.scs
# Written results/differential3.scs
# Written results/differential4.scs
# Written results/differential5.scs
